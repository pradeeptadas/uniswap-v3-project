# %%
import numpy as np
import logging
import sys
from uniswapv3_simulator.pool import Uniswapv3Pool
from uniswapv3_simulator.math import tick_to_sqrt_price

logging.basicConfig(level=logging.INFO, 
                    stream=sys.stdout)  # ensures logging and print statements are in correct order
logging.getLogger('uniswap-v3').setLevel(logging.DEBUG)

# %% [markdown]
# **Notes:**
# 1. `token0` = $x$, `token1` = $y$. $P = \frac{y}{x}$.
# 2. Swapping in `token1` (receiving `token0`) results in the price increasing as $y$ increases and $x$ decreases (i.e., move to the right).
# 2. Swapping in `token0` (receiving `token1`) results in the price decreasing as $y$ decreases and $x$ increases (i.e., move to the left).

# %% [markdown]
# **Test 1:** LP with a single position. Two swaps are executed, both within the the range of liquidity provided by the LP. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 0.1 of token0
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 0.1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 1 of token1
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 1)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove all liquidity from the pool
# token0, token1 output from set_position are positive, indicating the amount
# the LP received from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}')

# total fees owed to LP due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# fees owed to the single LP should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 0.1000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.0990.
# DEBUG:uniswap-v3.pool:token1 out: -0.9900.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0010
# DEBUG:uniswap-v3.pool:0.00000010 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,026.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0010.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.4148
# DEBUG:uniswap-v3.pool:Final token1 in pool: 2.1755
# Trader swapped 0.1000 of token0 for 0.9900 of token1
#
# Liquidity and virtual reserves after swap 1
# x: 3,162.38
# y: 31,621.79
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,026.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 0.9900.
# DEBUG:uniswap-v3.pool:token0 out: -0.0990.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0100
# DEBUG:uniswap-v3.pool:0.00000100 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,027.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0100.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.3158
# DEBUG:uniswap-v3.pool:Final token1 in pool: 3.1655
# Trader swapped 1.0000 of token1 for 0.0990 of token0
#
# Liquidity and virtual reserves after swap 2
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000010.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000100.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0010.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0100.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0010.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0100.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -3.1655
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.3158 of token0 and 3.1655 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
# Fees owed to LP
# Fees owed in token0: 0.0010
# Fees owed in token1: 0.0100
# Fees collected by pool
# Fees collected in token0: 0.0010
# Fees collected in token1: 0.0100

# %% [markdown]
# **Test 2:** LP with a single position. Two swaps are executed. The first within the range of liquidity provided by the LP. The second exhausts all liquidity of token0. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 0.1 of token0
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 0.1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 5 of token1
# this swap should exhaust all of the liquidity in the pool, leaving
# the pool with 0 of token0 and x of token1
# the swap will also only be partially executed as there is not enough 
# of token0 to execute the desired trade
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 5)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove all liquidity from the pool
# token0, token1 output from set_position are positive, indicating the amount
# the LP received from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}')

# total fees owed to LP due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# fees owed to the single LP should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 0.1000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.0990.
# DEBUG:uniswap-v3.pool:token1 out: -0.9900.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0010
# DEBUG:uniswap-v3.pool:0.00000010 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,026.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0010.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.4148
# DEBUG:uniswap-v3.pool:Final token1 in pool: 2.1755
# Trader swapped 0.1000 of token0 for 0.9900 of token1
#
# Liquidity and virtual reserves after swap 1
# x: 3,162.38
# y: 31,621.79
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 5.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,026.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 4.1488.
# DEBUG:uniswap-v3.pool:token0 out: -0.4148.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0419
# DEBUG:uniswap-v3.pool:0.00000419 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.8093.
# DEBUG:uniswap-v3.pool:Current tick: 23,029.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1626.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# WARNING:uniswap-v3.pool:Current price 3.1626 is at a limit point 3.1626. The swap may only be partially executed.
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0419.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.4148
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 4.1488
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.0000
# DEBUG:uniswap-v3.pool:Final token1 in pool: 6.3242
# Trader swapped 4.1907 of token1 for 0.4148 of token0
#
# Liquidity and virtual reserves after swap 2
# x: 3,161.96
# y: 31,625.94
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000010.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000419.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0010.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0419.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0010.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0419.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -6.3242
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.0000 of token0 and 6.3242 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
# Fees owed to LP
# Fees owed in token0: 0.0010
# Fees owed in token1: 0.0419
# Fees collected by pool
# Fees collected in token0: 0.0010
# Fees collected in token1: 0.0419

# %% [markdown]
# **Test 3:** LP with a single position. Two swaps are executed. The first within the range of liquidity provided by the LP. The second exhausts all liquidity of token1. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 1 of token1
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 1)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 1 of token0
# this swap should exhaust all of the liquidity in the pool, leaving
# the pool with x of token0 and 0 of token1
# the swap will also only be partially executed as there is not enough 
# of token0 to execute the desired trade
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove all liquidity from the pool
# token0, token1 output from set_position are positive, indicating the amount
# the LP received from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}')

# total fees owed to LP due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# fees owed to the single LP should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 0.9900.
# DEBUG:uniswap-v3.pool:token0 out: -0.0990.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0100
# DEBUG:uniswap-v3.pool:0.00000100 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,027.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1624.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0100.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.2169
# DEBUG:uniswap-v3.pool:Final token1 in pool: 4.1554
# Trader swapped 1.0000 of token1 for 0.0990 of token0
#
# Liquidity and virtual reserves after swap 1
# x: 3,162.18
# y: 31,623.77
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1624.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.4156.
# DEBUG:uniswap-v3.pool:token1 out: -4.1554.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0042
# DEBUG:uniswap-v3.pool:0.00000042 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.5802.
# DEBUG:uniswap-v3.pool:Current tick: 23,025.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1620.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# WARNING:uniswap-v3.pool:Current price 3.1620 is at a limit point 3.1620. The swap may only be partially executed.
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0042.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.4156
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -4.1554
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.6324
# DEBUG:uniswap-v3.pool:Final token1 in pool: 0.0000
# Trader swapped 0.4198 of token0 for 4.1554 of token1
#
# Liquidity and virtual reserves after swap 2
# x: 3,162.59
# y: 31,619.61
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000042.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000100.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0042.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0100.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0042.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0100.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.6324
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -0.0000
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.6324 of token0 and 0.0000 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
# Fees owed to LP
# Fees owed in token0: 0.0042
# Fees owed in token1: 0.0100
# Fees collected by pool
# Fees collected in token0: 0.0042
# Fees collected in token1: 0.0100

# %% [markdown]
# **Test 4:** LP with a single position. Swaps alternate between exhausting each token, and try to execute swaps when the pool is missing required tokens. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 5 of token1
# this swap should exhaust all of the liquidity in the pool, leaving
# the pool with 0 of token0 and x of token1
# the swap will also only be partially executed as there is not enough 
# of token0 to execute the desired trade
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 5)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# swap 1 of token1
# this swap should not execute as we are already at a limit point
token0, token1 = pool.swap(1, 1)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 1 of token0
# this swap should exhaust all of the liquidity in the pool, leaving
# the pool with x of token0 and 0 of token1
# the swap will also only be partially executed as there is not enough 
# of token0 to execute the desired trade
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# swap 0.1 of token0
# this swap should not execute as we are already at a limit point
token0, token1 = pool.swap(0, 0.1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove all liquidity from the pool
# token0, token1 output from set_position are positive, indicating the amount
# the LP received from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}')

# total fees owed to LP due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# fees owed to the single LP should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 5.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 3.1588.
# DEBUG:uniswap-v3.pool:token0 out: -0.3158.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0319
# DEBUG:uniswap-v3.pool:0.00000319 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 1.8093.
# DEBUG:uniswap-v3.pool:Current tick: 23,029.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1626.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# WARNING:uniswap-v3.pool:Current price 3.1626 is at a limit point 3.1626. The swap may only be partially executed.
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0319.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.3158
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 3.1588
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.0000
# DEBUG:uniswap-v3.pool:Final token1 in pool: 6.3242
# Trader swapped 3.1907 of token1 for 0.3158 of token0
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,029.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1626.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# WARNING:uniswap-v3.pool:Current price 3.1626 is at a limit point 3.1626. The swap may only be partially executed.
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0000.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.0000
# DEBUG:uniswap-v3.pool:Final token1 in pool: 6.3242
# Trader swapped 0.0000 of token1 for 0.0000 of token0
#
# Liquidity and virtual reserves after swap 1
# x: 3,161.96
# y: 31,625.94
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,029.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1626.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.6324.
# DEBUG:uniswap-v3.pool:token1 out: -6.3242.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0064
# DEBUG:uniswap-v3.pool:0.00000064 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.3612.
# DEBUG:uniswap-v3.pool:Current tick: 23,025.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1620.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# WARNING:uniswap-v3.pool:Current price 3.1620 is at a limit point 3.1620. The swap may only be partially executed.
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0064.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.6324
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -6.3242
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.6324
# DEBUG:uniswap-v3.pool:Final token1 in pool: 0.0000
# Trader swapped 0.6388 of token0 for 6.3242 of token1
#
# DEBUG:uniswap-v3.pool:Swapping 0.1000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,025.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1620.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# WARNING:uniswap-v3.pool:Current price 3.1620 is at a limit point 3.1620. The swap may only be partially executed.
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0000.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.6324
# DEBUG:uniswap-v3.pool:Final token1 in pool: 0.0000
# Trader swapped 0.0000 of token0 for 0.0000 of token1
#
# Liquidity and virtual reserves after swap 2
# x: 3,162.59
# y: 31,619.61
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000064.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000319.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0064.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0319.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0064.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0319.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.6324
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -0.0000
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.6324 of token0 and 0.0000 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
# Fees owed to LP
# Fees owed in token0: 0.0064
# Fees owed in token1: 0.0319
# Fees collected by pool
# Fees collected in token0: 0.0064
# Fees collected in token1: 0.0319

# %% [markdown]
# **Test 5:** Two LP positions. Two swaps are executed, both within the the range of liquidity provided by the LP. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# add a second position with a larger range
# both positions have the same liquidity, so this position will need to be 
# contribute more tokens
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick + 4, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 0.1 of token0
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 0.1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 1 of token1
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 1)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove the first position from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# remove the second position from the pool
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick + 4, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}\n')

# total fees owed to first position due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP - position 1')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# total fees owed to second position due to transaction(s)
position = pool.position_map[('id1', start_tick - 4, start_tick + 4)]
print('Fees owed to LP - position 2')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}\n')

# since both positions have the same liquidity and transactions
# occured within both positions' ranges, the two positions
# should have the same fees
# total fees owed to the two LP positions should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# DEBUG:uniswap-v3.tick:Tick 23,023 initialized (sqrt_price=3.1616).
# DEBUG:uniswap-v3.tick:Tick 23,031 initialized (sqrt_price=3.1629).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,023, 23,031 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.6320
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 6.3271
# LP must provide 0.6320 of token0 and 6.3271 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 6,324.56
# y: 63,245.55
# Calculated pool liquidity: 20,000.00
# Actual pool liquidity: 20,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 0.1000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.0990.
# DEBUG:uniswap-v3.pool:token1 out: -0.9900.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0010
# DEBUG:uniswap-v3.pool:0.00000005 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,026.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Current liquidity: 20,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0010.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 1.0469
# DEBUG:uniswap-v3.pool:Final token1 in pool: 8.5025
# Trader swapped 0.1000 of token0 for 0.9900 of token1
#
# Liquidity and virtual reserves after swap 1
# x: 6,324.65
# y: 63,244.56
# Calculated pool liquidity: 20,000.00
# Actual pool liquidity: 20,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,026.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Starting liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 0.9900.
# DEBUG:uniswap-v3.pool:token0 out: -0.0990.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0100
# DEBUG:uniswap-v3.pool:0.00000050 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,027.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Current liquidity: 20,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0100.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.9479
# DEBUG:uniswap-v3.pool:Final token1 in pool: 9.4925
# Trader swapped 1.0000 of token1 for 0.0990 of token0
#
# Liquidity and virtual reserves after swap 2
# x: 6,324.56
# y: 63,245.55
# Calculated pool liquidity: 20,000.00
# Actual pool liquidity: 20,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000005.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000050.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0005.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0050.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0005.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0050.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -3.1655
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.3158 of token0 and 3.1655 of token1
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000005.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000050.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0005.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0050.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0005.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0050.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.6320
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -6.3271
# DEBUG:uniswap-v3.pool:Tick 23,023 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,031 no longer has liquidity referencing it and was deleted.
# LP received 0.6320 of token0 and 6.3271 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
#
# Fees owed to LP - position 1
# Fees owed in token0: 0.0005
# Fees owed in token1: 0.0050
# Fees owed to LP - position 2
# Fees owed in token0: 0.0005
# Fees owed in token1: 0.0050
#
# Fees collected by pool
# Fees collected in token0: 0.0010
# Fees collected in token1: 0.0100

# %% [markdown]
# **Test 6:** Two LP positions, but one is initialized after the first swap. Two swaps are executed, both within the the range of liquidity provided by the LP. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 0.1 of token0
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 0.1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# add a second position with a larger range
# both positions have the same liquidity, so this position will need to be 
# contribute more tokens
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick + 4, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# swap 1 of token1
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 1)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# liquidity will be different now as we have added a position
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after position 2 added and swap 2 executed')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove the first position from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# remove the second position from the pool
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick + 4, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}\n')

# total fees owed to first position due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP - position 1')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# total fees owed to second position due to transaction(s)
position = pool.position_map[('id1', start_tick - 4, start_tick + 4)]
print('Fees owed to LP - position 2')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}\n')

# the first position should have the fees from the first swap while the 
# fees from the second swap should be split evenly between the positions
# total fees owed to the two LP positions should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 0.1000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.0990.
# DEBUG:uniswap-v3.pool:token1 out: -0.9900.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0010
# DEBUG:uniswap-v3.pool:0.00000010 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,026.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0010.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.4148
# DEBUG:uniswap-v3.pool:Final token1 in pool: 2.1755
# Trader swapped 0.1000 of token0 for 0.9900 of token1
#
# Liquidity and virtual reserves after swap 1
# x: 3,162.38
# y: 31,621.79
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.tick:Tick 23,023 initialized (sqrt_price=3.1616).
# DEBUG:uniswap-v3.tick:Tick 23,031 initialized (sqrt_price=3.1629).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,023, 23,031 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.7310
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 5.3371
# LP must provide 0.7310 of token0 and 5.3371 of token1
#
# DEBUG:uniswap-v3.pool:Swapping 1.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,026.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Starting liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 0.9900.
# DEBUG:uniswap-v3.pool:token0 out: -0.0990.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0100
# DEBUG:uniswap-v3.pool:0.00000050 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,026.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Current liquidity: 20,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0100.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 1.0469
# DEBUG:uniswap-v3.pool:Final token1 in pool: 8.5026
# Trader swapped 1.0000 of token1 for 0.0990 of token0
#
# Liquidity and virtual reserves after position 2 added and swap 2 executed
# x: 6,324.65
# y: 63,244.56
# Calculated pool liquidity: 20,000.00
# Actual pool liquidity: 20,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000010.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000050.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0010.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0050.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0010.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0050.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.3653
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -2.6705
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.3653 of token0 and 2.6705 of token1
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000050.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0050.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0050.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.6815
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -5.8321
# DEBUG:uniswap-v3.pool:Tick 23,023 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,031 no longer has liquidity referencing it and was deleted.
# LP received 0.6815 of token0 and 5.8321 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
#
# Fees owed to LP - position 1
# Fees owed in token0: 0.0010
# Fees owed in token1: 0.0050
# Fees owed to LP - position 2
# Fees owed in token0: 0.0000
# Fees owed in token1: 0.0050
#
# Fees collected by pool
# Fees collected in token0: 0.0010
# Fees collected in token1: 0.0100

# %% [markdown]
# **Test 7:** Two LP positions. Two swaps are executed, the first is within the the range of liquidity of both positions, but the second crosses the tick of the first position. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}\n')

# contribute liquidity to the pool
# token0, token1 output from set_position are negative, indicating the amount
# the LP must provide tokens to the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# add a second position with a larger range
# both positions have the same liquidity, so this position will need to be 
# contribute more tokens
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick + 4, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the initial liquidity values
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 0.1 of token0
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 0.1)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 10 of token1
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 10)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# now that we crossed the first tick, liquidity should be reduced 
# from 20,000 -> 10,000
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove the first position from the pool
token0, token1 = pool.set_position('id1', start_tick - 2, start_tick + 2, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# remove the second position from the pool
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick + 4, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}\n')

# total fees owed to first position due to transaction(s)
position = pool.position_map[('id1', start_tick - 2, start_tick + 2)]
print('Fees owed to LP - position 1')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}')

# total fees owed to second position due to transaction(s)
position = pool.position_map[('id1', start_tick - 4, start_tick + 4)]
print('Fees owed to LP - position 2')
print(f'Fees owed in token0: {position.tokens_owed0:,.4f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.4f}\n')

# fees from first swap (token0) should be split evenly between positions
# as swap occured within the the range of both positions
# the second position should have a larger share of the fees from the
# second swap (token1) as part of the swap was executed within the shared
# range, but the upper tick for the first position was crossed and the 
# rest of the swap occured where only the second position provided liquidity
# so the remaining fees went to the second position
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
#
# DEBUG:uniswap-v3.tick:Tick 23,025 initialized (sqrt_price=3.1620).
# DEBUG:uniswap-v3.tick:Tick 23,029 initialized (sqrt_price=3.1626).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,025, 23,029 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.3158
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 3.1654
# LP must provide 0.3158 of token0 and 3.1654 of token1
#
# DEBUG:uniswap-v3.tick:Tick 23,023 initialized (sqrt_price=3.1616).
# DEBUG:uniswap-v3.tick:Tick 23,031 initialized (sqrt_price=3.1629).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,023, 23,031 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.6320
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 6.3271
# LP must provide 0.6320 of token0 and 6.3271 of token1
#
# Liquidity and virtual reserves before any swaps
# x: 6,324.56
# y: 63,245.55
# Calculated pool liquidity: 20,000.00
# Actual pool liquidity: 20,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 0.1000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,025.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1620.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.0990.
# DEBUG:uniswap-v3.pool:token1 out: -0.9900.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0010
# DEBUG:uniswap-v3.pool:0.00000005 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,026.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Current liquidity: 20,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0010.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.0990
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -0.9900
# DEBUG:uniswap-v3.pool:Final token0 in pool: 1.0469
# DEBUG:uniswap-v3.pool:Final token1 in pool: 8.5025
# Trader swapped 0.1000 of token0 for 0.9900 of token1
#
# Liquidity and virtual reserves after swap 1
# x: 6,324.65
# y: 63,244.56
# Calculated pool liquidity: 20,000.00
# Actual pool liquidity: 20,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 10.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,026.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1622.
# DEBUG:uniswap-v3.pool:Starting liquidity: 20,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,029.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1626.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 7.3076.
# DEBUG:uniswap-v3.pool:token0 out: -0.7307.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0738
# DEBUG:uniswap-v3.pool:0.00000369 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 2.6186.
# DEBUG:uniswap-v3.pool:Crossing tick 23,029.
# DEBUG:uniswap-v3.pool:Liquidity added from tick: -10,000.00
# DEBUG:uniswap-v3.tick:Fee growth outside token0 updated: 0.00000005.
# DEBUG:uniswap-v3.tick:Fee growth outside token1 updated: 0.00000369.
# DEBUG:uniswap-v3.pool:Current tick: 23,029.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1626.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,031.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1629.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 2.5924.
# DEBUG:uniswap-v3.pool:token0 out: -0.2592.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0262
# DEBUG:uniswap-v3.pool:0.00000262 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,030.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1629.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.1000.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.9899
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 9.9000
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.0570
# DEBUG:uniswap-v3.pool:Final token1 in pool: 18.4025
# Trader swapped 10.0000 of token1 for 0.9899 of token0
#
# Liquidity and virtual reserves after swap 2
# x: 3,161.70
# y: 31,628.53
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000005.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000369.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0005.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0369.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0005.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0369.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,025.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,029.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -6.3242
# DEBUG:uniswap-v3.pool:Tick 23,025 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,029 no longer has liquidity referencing it and was deleted.
# LP received 0.0000 of token0 and 6.3242 of token1
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000005.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000631.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0005.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0631.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0005.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0631.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.0570
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -12.0783
# DEBUG:uniswap-v3.pool:Tick 23,023 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,031 no longer has liquidity referencing it and was deleted.
# LP received 0.0570 of token0 and 12.0783 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
#
# Fees owed to LP - position 1
# Fees owed in token0: 0.0005
# Fees owed in token1: 0.0369
# Fees owed to LP - position 2
# Fees owed in token0: 0.0005
# Fees owed in token1: 0.0631
#
# Fees collected by pool
# Fees collected in token0: 0.0010
# Fees collected in token1: 0.1000

# %% [markdown]
# **Test 8:** Two LP positions side by side (no shared range). Two swaps are executed, crossing between the position ranges. LP removes all liquidity (and is able to collect fees).

# %%
# initialize pool
pool = Uniswapv3Pool(0.01, 1, 10)
start_tick = pool.tick
print(pool)
print(f'Starting tick: {start_tick:,}')
print(f'Starting tick sqrt_price: {tick_to_sqrt_price(start_tick):,.8f}')
print(f'Start sqrt_price:         {pool.sqrt_price:,.8f}\n')

# contribute liquidity to the pool on one side of the current price/tick
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# add a second position to the on the other side of the current price/tick
token0, token1 = pool.set_position('id1', start_tick, start_tick + 4, 10000)
print(f'LP must provide {-token0:,.4f} of token0 and {-token1:,.4f} of token1\n')

# check the total tokens in the pool
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}\n')

# check the initial liquidity values
# the start price is a little above tick 23,027, so the price is within the
# second position's range so we should only have 10,000 of liquidity
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves before any swaps')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 0.2 of token0
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token0 is negative as the trader provides this to the pool
# token1 is positive as the trader receives this from the pool
token0, token1 = pool.swap(0, 0.2)
print(f'Trader swapped {-token0:,.4f} of token0 for {token1:,.4f} of token1\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 1')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# swap 5 of token1
# this swap should execute entirely within the current tick range 
# i.e., no ticks should need to be crossed
# token1 is negative as the trader provides this to the pool
# token0 is positive as the trader receives this from the pool
token0, token1 = pool.swap(1, 5)
print(f'Trader swapped {-token1:,.4f} of token1 for {token0:,.4f} of token0\n')

# since we have not crossed any ticks, liquidity should not have changed
x, y = pool.virtual_reserves
print('Liquidity and virtual reserves after swap 2')
print(f'x: {x:,.2f}')
print(f'y: {y:,.2f}')
print(f'Calculated pool liquidity: {np.sqrt(x * y):,.2f}')
print(f'Actual pool liquidity: {pool.liquidity:,.2f}\n')

# remove the first position from the pool
token0, token1 = pool.set_position('id1', start_tick - 4, start_tick, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# remove the second position from the pool
token0, token1 = pool.set_position('id1', start_tick, start_tick + 4, -10000)
print(f'LP received {token0:,.4f} of token0 and {token1:,.4f} of token1\n')

# since all liquidity was removed, the pool should have 0 
# of token0 and token1
print('Total tokens in pool')
print(f'Pool token0: {pool.token0:,.4f}')
print(f'Pool token1: {pool.token1:,.4f}\n')

# total fees owed to first position due to transaction(s)
position = pool.position_map[('id1', start_tick - 4, start_tick)]
print('Fees owed to LP - position 1')
print(f'Fees owed in token0: {position.tokens_owed0:,.8f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.8f}')

# total fees owed to second position due to transaction(s)
position = pool.position_map[('id1', start_tick, start_tick + 4)]
print('Fees owed to LP - position 2')
print(f'Fees owed in token0: {position.tokens_owed0:,.8f}')
print(f'Fees owed in token1: {position.tokens_owed1:,.8f}\n')

# since both positions have the same liquidity and transactions
# occured within both positions' ranges, the two positions
# should have the same fees
# total fees owed to the two LP positions should match total fees collected
# by the pool as well
print('Fees collected by pool')
print(f'Fees collected in token0: {pool.total_fees_token0:,.4f}')
print(f'Fees collected in token1: {pool.total_fees_token1:,.4f}')
# Out:
# Pool(price=10.0000, liquidity=0.00, fee=1.00%)
# Starting tick: 23,027
# Starting tick sqrt_price: 3.16227731
# Start sqrt_price:         3.16227766
#
# DEBUG:uniswap-v3.tick:Tick 23,023 initialized (sqrt_price=3.1616).
# DEBUG:uniswap-v3.tick:Tick 23,027 initialized (sqrt_price=3.1623).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,023, 23,027 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,027.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 6.3236
# LP must provide 0.0000 of token0 and 6.3236 of token1
#
# DEBUG:uniswap-v3.tick:Tick 23,031 initialized (sqrt_price=3.1629).
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.position:Position id1, 23,027, 23,031 initialized.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:Updated position liquidity: 10,000.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0000.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity added to tick 23,027.
# DEBUG:uniswap-v3.tick:10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.6320
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: 0.0035
# LP must provide 0.6320 of token0 and 0.0035 of token1
#
# Total tokens in pool
# Pool token0: 0.6320
# Pool token1: 6.3271
#
# Liquidity and virtual reserves before any swaps
# x: 3,162.28
# y: 31,622.78
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 0.2000 of token0.
# DEBUG:uniswap-v3.pool:Starting tick: 23,027.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,027.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1623.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.0003.
# DEBUG:uniswap-v3.pool:token1 out: -0.0035.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0000
# DEBUG:uniswap-v3.pool:0.00000000 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.1996.
# DEBUG:uniswap-v3.pool:Crossing tick 23,027.
# DEBUG:uniswap-v3.pool:Liquidity added from tick: 0.00
# DEBUG:uniswap-v3.tick:Fee growth outside token0 updated: 0.00000000.
# DEBUG:uniswap-v3.tick:Fee growth outside token1 updated: 0.00000000.
# DEBUG:uniswap-v3.pool:Current tick: 23,027.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,023.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1616.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token0 in: 0.1977.
# DEBUG:uniswap-v3.pool:token1 out: -1.9764.
# DEBUG:uniswap-v3.pool:Fees earned (in token0): 0.0020
# DEBUG:uniswap-v3.pool:0.00000020 added to fee_growth_global0.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,025.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1621.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token0: 0.0020.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: 0.1980
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: -1.9799
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.8300
# DEBUG:uniswap-v3.pool:Final token1 in pool: 4.3472
# Trader swapped 0.2000 of token0 for 1.9799 of token1
#
# Liquidity and virtual reserves after swap 1
# x: 3,162.48
# y: 31,620.80
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:Swapping 5.0000 of token1.
# DEBUG:uniswap-v3.pool:Starting tick: 23,025.
# DEBUG:uniswap-v3.pool:Starting sqrt_price: 3.1621.
# DEBUG:uniswap-v3.pool:Starting liquidity: 10,000.00.
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,027.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1623.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 1.9764.
# DEBUG:uniswap-v3.pool:token0 out: -0.1977.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0200
# DEBUG:uniswap-v3.pool:0.00000200 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 3.0036.
# DEBUG:uniswap-v3.pool:Crossing tick 23,027.
# DEBUG:uniswap-v3.pool:Liquidity added from tick: 0.00
# DEBUG:uniswap-v3.tick:Fee growth outside token0 updated: 0.00000020.
# DEBUG:uniswap-v3.tick:Fee growth outside token1 updated: 0.00000200.
# DEBUG:uniswap-v3.pool:Current tick: 23,027.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1623.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Next initialized tick: 23,031.
# DEBUG:uniswap-v3.pool:sqrt_price of next tick: 3.1629.
# DEBUG:uniswap-v3.pool:Next tick is the min/max tick initialized.
# DEBUG:uniswap-v3.pool:Completed swap within current tick range.
# DEBUG:uniswap-v3.pool:token1 in: 2.9736.
# DEBUG:uniswap-v3.pool:token0 out: -0.2973.
# DEBUG:uniswap-v3.pool:Fees earned (in token1): 0.0300
# DEBUG:uniswap-v3.pool:0.00000300 added to fee_growth_global1.
# DEBUG:uniswap-v3.pool:Amount remaining to swap: 0.0000.
# DEBUG:uniswap-v3.pool:Current tick: 23,028.
# DEBUG:uniswap-v3.pool:Current sqrt_price: 3.1626.
# DEBUG:uniswap-v3.pool:Current liquidity: 10,000.00
# DEBUG:uniswap-v3.pool:Swap complete.
# DEBUG:uniswap-v3.pool:Total fees earned in token1: 0.0500.
# DEBUG:uniswap-v3.pool:Total token0 added to/removed from pool: -0.4950
# DEBUG:uniswap-v3.pool:Total token1 added to/removed from pool: 4.9500
# DEBUG:uniswap-v3.pool:Final token0 in pool: 0.3350
# DEBUG:uniswap-v3.pool:Final token1 in pool: 9.2972
# Trader swapped 5.0000 of token1 for 0.4950 of token0
#
# Liquidity and virtual reserves after swap 2
# x: 3,161.98
# y: 31,625.75
# Calculated pool liquidity: 10,000.00
# Actual pool liquidity: 10,000.00
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000020.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000200.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0020.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0200.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0020.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0200.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,023.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,027.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: 0.0000
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -6.3236
# DEBUG:uniswap-v3.pool:Tick 23,023 no longer has liquidity referencing it and was deleted.
# LP received 0.0000 of token0 and 6.3236 of token1
#
# DEBUG:uniswap-v3.pool:token0 fee growth inside position range: 0.00000000.
# DEBUG:uniswap-v3.pool:token1 fee growth inside position range: 0.00000300.
# DEBUG:uniswap-v3.position:token0 uncollected fees: 0.0000.
# DEBUG:uniswap-v3.position:token1 uncollected fees: 0.0300.
# DEBUG:uniswap-v3.position:Updated position liquidity: 0.00.
# DEBUG:uniswap-v3.position:Total token0 owed: 0.0000.
# DEBUG:uniswap-v3.position:Total token1 owed: 0.0300.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity added to tick 23,027.
# DEBUG:uniswap-v3.tick:-10,000.00 liquidity subtracted from tick 23,031.
# DEBUG:uniswap-v3.pool:liquidity_delta added to liquidity.
# DEBUG:uniswap-v3.pool:Updated liquidity: 0.00.
# DEBUG:uniswap-v3.pool:token0 added to/removed from pool: -0.3350
# DEBUG:uniswap-v3.pool:token1 added to/removed from pool: -2.9736
# DEBUG:uniswap-v3.pool:Tick 23,027 no longer has liquidity referencing it and was deleted.
# DEBUG:uniswap-v3.pool:Tick 23,031 no longer has liquidity referencing it and was deleted.
# LP received 0.3350 of token0 and 2.9736 of token1
#
# Total tokens in pool
# Pool token0: 0.0000
# Pool token1: 0.0000
#
# Fees owed to LP - position 1
# Fees owed in token0: 0.00199648
# Fees owed in token1: 0.01996356
# Fees owed to LP - position 2
# Fees owed in token0: 0.00000352
# Fees owed in token1: 0.03003644
#
# Fees collected by pool
# Fees collected in token0: 0.0020
# Fees collected in token1: 0.0500
